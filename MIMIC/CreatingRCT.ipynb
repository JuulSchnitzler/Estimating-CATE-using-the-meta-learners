# %%
import pandas as pd

# %%
# Exploring MIMIC dataset
RCT = pd.read_csv("./bsc_project_set.csv")

# %%
# Drop columns that are not present in RCT (to have a 'RCT' like dataset), used for external validation
RCT = RCT.drop(columns=['map', 'bilirubin', 'creatinine', 'platelets', 'urea', 'diastolic_blood_pressure'], axis=1)
RCT.head()
# Out:
#    Unnamed: 0        id  mort_28  age sex  weight  height    pf_ratio  \
# 0           0  32128372    False   75   F    93.0   168.0  241.944444
# 1           1  34100191    False   47   M   127.0   183.0  166.356061
# 2           2  38292466    False   85   M    77.5   170.0  224.000000
# 3           3  32743332    False   85   M    90.7   170.0  205.714286
# 4           4  35009126     True   64   M    70.0   183.0  173.777778
#
#           po2       pco2  ...  lung_compliance       fio2       hco3  \
# 0  130.666667  28.111111  ...        31.227273  50.000000  12.000000
# 1  113.076923  34.461538  ...        79.780702  68.500000  12.750000
# 2  112.000000  38.000000  ...        33.338235  51.818182  23.000000
# 3   72.000000  38.000000  ...        26.882353  36.875000  27.000000
# 4   94.666667  38.666667  ...        52.821226  52.500000  21.666667
#
#    heart_rate  minute_volume      peep  plateau_pressure  respiratory_rate  \
# ...

# %%
RCT.to_csv('.\RCT.csv')
